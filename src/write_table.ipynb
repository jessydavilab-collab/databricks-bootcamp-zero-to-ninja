# %%
df = spark.read.table("samples.bakehouse.sales_customers")

df.write.mode("overwrite").saveAsTable("bronce_dev.bakehouse.customers_brz")

# %%
df = spark.read.table("samples.bakehouse.sales_franchises")

df.write.mode("overwrite").saveAsTable("bronce_dev.bakehouse.franchises_brz")

# %%
df = spark.read.table("samples.bakehouse.sales_suppliers")

df.write.mode("overwrite").saveAsTable("bronce_dev.bakehouse.suppliers_brz")

# %%
df = spark.read.table("samples.bakehouse.sales_transactions")

df.write.mode("overwrite").saveAsTable("bronce_dev.bakehouse.transactions_brz")
